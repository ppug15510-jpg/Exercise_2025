# %% [markdown]
# <a href="https://colab.research.google.com/github/ppug15510-jpg/Exercise_2025/blob/main/140try~except_Exception_as_e_141try~except.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#140 예외처리 4: try~except Exception as e
intList = range(10)
idx = 10
try:
  print(intList[idx])
except Exception as e:
  exceptionClass = e.__class__.__name__
  exceptionDetail = e.__str__() #print(e) = print(e.__str__())
  print(f'예외종류: {exceptionClass}, 예외내용: {exceptionDetail}')
# Out:
# 예외종류: IndexError, 예외내용: range object index out of range

# %%
intList = range(10)
idx = 10
try:
  print(intList[idx])
except Exception as e:
  exceptionClass = e.__class__.__name__
  exceptionDetail = e.__str__() #print(e) = print(e.__str__())
  print(f'예외종류: {exceptionClass}, 예외내용: {e}')
# Out:
# 예외종류: IndexError, 예외내용: range object index out of range

# %%
#141 예외처리 5: try~except 특정예외
intList = range(10)
try:
  idx = int(input('숫자를 입력하세요:'))
  print(intList[idx])
except ValueError:
  print('입력한 내용이 숫자가 아닙니다!')
except IndexError as e:
  print(f'인덱스 오류가 발생:{e}')
# Out:
# 숫자를 입력하세요:a
# 입력한 내용이 숫자가 아닙니다!

# %%
intList = range(10)
try:
  idx = int(input('숫자를 입력하세요:'))
  print(intList[idx])
except ValueError:
  print('입력한 내용이 숫자가 아닙니다!')
except IndexError as e:
  print(f'인덱스 오류가 발생:{e}')
# Out:
# 숫자를 입력하세요:12
# 인덱스 오류가 발생:range object index out of range
