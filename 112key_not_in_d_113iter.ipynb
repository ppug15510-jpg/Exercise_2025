# %% [markdown]
# <a href="https://colab.research.google.com/github/ppug15510-jpg/Exercise_2025/blob/main/112key_not_in_d_113iter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#112 딕셔너리에 특정 키가 없는지 확인: key not in d
frequency = {}
while True:
  c = input('알파벳 1자를 입력하세요[끝내려면 엔터를 치세요]:')
  if c =='':
    break
  if c not in frequency:
    frequency[c] = 1
  else:
    frequency[c] += 1
  print(frequency)
# Out:
# 알파벳 1자를 입력하세요[끝내려면 엔터를 치세요]:a
# {'a': 1}
# 알파벳 1자를 입력하세요[끝내려면 엔터를 치세요]:b
# {'a': 1, 'b': 1}
# 알파벳 1자를 입력하세요[끝내려면 엔터를 치세요]:c
# {'a': 1, 'b': 1, 'c': 1}
# 알파벳 1자를 입력하세요[끝내려면 엔터를 치세요]:a
# {'a': 2, 'b': 1, 'c': 1}
# 알파벳 1자를 입력하세요[끝내려면 엔터를 치세요]:c
# {'a': 2, 'b': 1, 'c': 2}

# %%
#113 딕셔너리의 모든 키로 이터레이터 생성: iter(d)
greats = {'유비':89, '관우':95, '장비':91, '조운':94}
for name in iter(greats):
  print(name)
# Out:
# 유비
# 관우
# 장비
# 조운
