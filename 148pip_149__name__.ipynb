# %% [markdown]
# <a href="https://colab.research.google.com/github/ppug15510-jpg/Exercise_2025/blob/main/148pip_149__name__.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#148 외부 모듈/패키지 설치 도구: pip
import matplotlib

# %%
#149 if __name__ == '__main__':
def printName():
  print(f'module_b의 __name__ = {__name__}')

# %%
from module_b import printName

printName()
print(f'실행 모듈인 이 모듈의 __name__ = {__name__}')
