# %% [markdown]
# <a href="https://colab.research.google.com/github/ppug15510-jpg/Exercise_2025/blob/main/186asyncio_187opencv1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#186 비동기 함수 구현하기: asyncio, async, await
import asyncio
from time import time

async def sayAfter(delay, saying):
  print(f'sayAfter({delay},saying) 시작...')
  await asyncio.sleep(delay)
  print(saying)

# %%
async def main():
  print('비동기 함수 main() 시작...')
  stime = time()
  await sayAfter(1, '안녕하세요!')
  await sayAfter(2, '방가방가~~')
  etime = time()
  print(f'총 소요 시간: {etime-stime:.2f}초')

asyncio.run(main()) #주피터 노트북에서 실행시 오류 발생됨
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipython-input-2894123068.py in <cell line: 0>()
#       7   print(f'총 소요 시간: {etime-stime:.2f}초')
#       8
# ----> 9 asyncio.run(main()) #주피터 노트북에서 실행시 오류 발생됨
#
# /usr/lib/python3.12/asyncio/runners.py in run(main, debug, loop_factory)
#     189     if events._get_running_loop() is not None:
#     190         # fail fast with short traceback
# --> 191         raise RuntimeError(
#     192             "asyncio.run() cannot be called from a running event loop")
#     193
#
# RuntimeError: asyncio.run() cannot be called from a running event loop

# %%
async def main():
  print('비동기 함수 main() 시작...')
  stime = time()
  await sayAfter(1, '안녕하세요!')
  await sayAfter(2, '방가방가~~')
  etime = time()
  print(f'총 소요 시간: {etime-stime:.2f}초')

await main()
# Out:
# 비동기 함수 main() 시작...
# sayAfter(1,saying) 시작...
# 안녕하세요!
# sayAfter(2,saying) 시작...
# 방가방가~~
# 총 소요 시간: 3.00초

# %%
async def main():
    print('비동기 함수 main() 시작...')
    tasks = []
    tasks.append(asyncio.create_task(sayAfter(1, '안녕하세요!')))
    tasks.append(asyncio.create_task(sayAfter(2, '방가방가~~')))

    stime = time()
    await asyncio.wait(tasks)
    etime = time()
    print(f'총 소요 시간: {etime-stime:.2f}초')

await main() # 주피터 노트북이 아니면 asyncio.run(main())으로 실행!
# Out:
# 비동기 함수 main() 시작...
# sayAfter(1,saying) 시작...
# 안녕하세요!
# sayAfter(2,saying) 시작...
# 방가방가~~
# 총 소요 시간: 3.00초

# %%
from time import sleep

async def sayAfter(delay, saying):
  print(f'sayAfter({delay},saying) 시작...')
  #await asyncio.sleep(delay)
  sleep(delay)
  print(saying)

# %%
#187 opencv를 활용하여 마우스로 도형 그리기 1
import cv2

def showImage(imgfile):
    img = cv2.imread(imgfile, cv2.IMREAD_COLOR)
    cv2.namedWindow('picture', cv2.WINDOW_AUTOSIZE)
    cv2.imshow('picture', img)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

showImage('sunrise.jpg')

# %%
import numpy as np
from random import shuffle

B = [i for i in range(256)] # Blue
G = [i for i in range(256)] # Green
R = [i for i in range(256)] # Red

# %%
def onMouse(event, x, y, flags, param):
    if event == cv2.EVENT_LBUTTONDBLCLK:
        shuffle(B), shuffle(G), shuffle(R)
        cv2.circle(param, (x, y), 50, [B[0], G[0], R[0]], -1)

# %%
def mouseBrush():
    img = np.zeros((576, 1024, 3), np.uint8)
    cv2.namedWindow('drawing pad')
    cv2.setMouseCallback('drawing pad', onMouse, img)

    while True:
        cv2.imshow('drawing pad', img)
        k = cv2.waitKey(1) & 0xFF
        if k == 27:
            break
    cv2.destroyAllWindows()

mouseBrush()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-668190286.py in <cell line: 0>()
#      11     cv2.destroyAllWindows()
#      12
# ---> 13 mouseBrush()
#
# /tmp/ipython-input-668190286.py in mouseBrush()
#       1 def mouseBrush():
#       2     img = np.zeros((576, 1024, 3), np.uint8)
# ----> 3     cv2.namedWindow('drawing pad')
#       4     cv2.setMouseCallback('drawing pad', onMouse, img)
#       5
#
# NameError: name 'cv2' is not defined
