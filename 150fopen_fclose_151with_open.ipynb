# %% [markdown]
# <a href="https://colab.research.google.com/github/ppug15510-jpg/Exercise_2025/blob/main/150fopen_fclose_151with_open.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#150 파일 열고 닫기: f.open(), f.close()
#텍스트 파일을 'CP949'인코딩으로 읽거나 쓰기
f = open('myfile.txt','w',encoding='cp949')
<파일 처리 코드>
f.close()

#바이너리 이미지 파일 읽기
f = open('image.jpg','rb')
<파일 처리 코드>
f.close()

# %%
#151 파일을 열고 자동으로 닫기: with open() as f
with open(파일경로, 모드, encoding=인코딩 방식) as 파일객체:
  <파일 처리 코드>

# %%
f = open('myfile.txt','r')
readData = f.readlines()
f.close()

# %%
with open('myfile.txt','r') as f:
  readData = f.readlines()
