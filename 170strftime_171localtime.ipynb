# %% [markdown]
# <a href="https://colab.research.google.com/github/ppug15510-jpg/Exercise_2025/blob/main/170strftime_171localtime.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#170 현재 시간을 연-월-일 시:분:초로 출력하기: time.localtime(), time.strftime()
from time import localtime, strftime

time_stamp = strftime('%Y-%m-%d %X',localtime())
print(f'현재시간:{time_stamp}')
# Out:
# 현재시간:2025-11-30 10:12:26

# %%
#171 올해의 경과된 날짜 수 계산: time.localtime()
from time import localtime,strftime

t = localtime()
today = strftime('%Y-%m-%d',t)
print(f'{today}은 {t.tm_year}-01-01 이후 {t.tm_yday}일째 되는 날입니다.')
# Out:
# 2025-11-30은 2025-01-01 이후 334일째 되는 날입니다.
