# %% [markdown]
# <a href="https://colab.research.google.com/github/ppug15510-jpg/Exercise_2025/blob/main/144module_145packages.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#144 모듈 이해하기
def splitFilename(file):
  buf = file.split('.')
  if len(buf) > 1:
    ext = buf[-1]
    fname = '.'.join(buf[:-1])
  else:
    fname = buf[0]
    ext = None
  return (fname, ext)

# %%
import splitfilename #splitfilename 모듈을 임포트

filename = 'python.200.study.py'
ret = splitfilename.splitFilename(filename)
print(f'파일 이름:{ret[0]}, 파일확장자:{ret[1]}')

# %%
#145 패키지 이해하기
import sound.filters.noraebang
