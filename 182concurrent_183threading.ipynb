# %% [markdown]
# <a href="https://colab.research.google.com/github/ppug15510-jpg/Exercise_2025/blob/main/182concurrent_183threading.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#182 동시 실행(Concurrent Execution) 개념
#multi-threading
#multi-process

# %%
#183 멀티스레드 프로그래밍: threading
from time import time

def checkPrimeNumber(x):
    ret = False

    if x == 2:
        return True
    if x <= 1 or x % 2 == 0:
        return False

    print(f'{x}: 소수인지 아닌지 판별 중...')
    stime = time()
    for i in range(3, int(x**(1/2))+1, 2):
        if x % i == 0:
            ret = False
            break
    else:
        ret = True
    etime = time()

    if ret:
        print(f'{x}:는 소수입니다. 소요 시간: {etime-stime:.2f}초')
    else:
        print(f'{x}:는 소수가 아닙니다.')

    return ret

# %%
def cumulativeSum(n):
    ret = 0
    print(f'{n}까지 누적합 계산 중...')
    stime = time()
    for i in range(1, n+1):
        ret += i
    etime = time()
    print(f'{n}까지 누적합 계산 시간 {etime-stime:.2f}초')
    print(f'누적합 결과: {ret:,}')
    return ret

# %%
x = 2305843009213693951
n = 1234567890
stime = time()
ret1 = checkPrimeNumber(x)
ret2 = cumulativeSum(n)
etime = time()
print(f'+++ 총 소요 시간 {etime-stime:.2f}초')
# Out:
# 2305843009213693951: 소수인지 아닌지 판별 중...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3902306160.py in <cell line: 0>()
#       2 n = 1234567890
#       3 stime = time()
# ----> 4 ret1 = checkPrimeNumber(x)
#       5 ret2 = cumulativeSum(n)
#       6 etime = time()
#
# /tmp/ipython-input-527895187.py in checkPrimeNumber(x)
#      13     stime = time()
#      14     for i in range(3, int(x**(1/2))+1, 2):
# ---> 15         if x % i == 0:
#      16             ret = False
#      17             break
#
# KeyboardInterrupt:

# %%
from threading import Thread

x = 2305843009213693951
n = 1234567890

t1 = Thread(target=checkPrimeNumber, args=(x,))
ret2 = cumulativeSum(n)
stime = time()
t1.start()
t1.join()
etime = time()
print(f'+++ 총 소요 시간 {etime-stime:.2f}초')
# Out:
# 1234567890까지 누적합 계산 중...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1321578565.py in <cell line: 0>()
#       5
#       6 t1 = Thread(target=checkPrimeNumber, args=(x,))
# ----> 7 ret2 = cumulativeSum(n)
#       8 stime = time()
#       9 t1.start()
#
# /tmp/ipython-input-1173409951.py in cumulativeSum(n)
#       4     stime = time()
#       5     for i in range(1, n+1):
# ----> 6         ret += i
#       7     etime = time()
#       8     print(f'{n}까지 누적합 계산 시간 {etime-stime:.2f}초')
#
# KeyboardInterrupt:

# %%
from threading import Thread

x = 2305843009213693951
n = 1234567890

t1 = Thread(target=checkPrimeNumber, args=(x,))
t2 = Thread(target=cumulativeSum, args=(n,))
stime = time()
t1.start()
t2.start()
t1.join()
t2.join()
etime = time()
print(f'+++ 총 소요 시간 {etime-stime:.2f}초')
# Out:
# 2305843009213693951: 소수인지 아닌지 판별 중...
# 1234567890까지 누적합 계산 중...
