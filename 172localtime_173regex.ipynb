# %% [markdown]
# <a href="https://colab.research.google.com/github/ppug15510-jpg/Exercise_2025/blob/main/172localtime_173regex.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#172 오늘의 요일 계산하기: time.localtime()
from time import localtime, strftime

weekdays = ['월요일','화요일','수요일','목요일','금요일','토요일','일요일']
t = localtime()
today = strftime('%Y-%m-%d',t)
print(f'{today}은 {weekdays[t.tm_wday]}입니다.')
# Out:
# 2025-11-30은 일요일입니다.

# %%
#173 정규표현식 개념
#?
#*
#+
#{m}
#{m,n}
#.
#^
#$
#|
#[]
#()
#\d
#\D
#\s
#\S
#\w
#\W
#\b
#\B
#\A
#\Z
