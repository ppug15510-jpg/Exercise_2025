# %% [markdown]
# <a href="https://colab.research.google.com/github/ppug15510-jpg/Exercise_2025/blob/main/122d1d2_123sorted.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#122 딕셔너리 갱신하기 2: d1|d2, d1|=d2
greats = {'유비':89, '관우':95, '장비':91, '조운':94}
others = {'제갈량':99, '황충':70}
updated = greats|others
print(updated)
# Out:
# {'유비': 89, '관우': 95, '장비': 91, '조운': 94, '제갈량': 99, '황충': 70}

# %%
updated2 = updated|{'유비':90, '관우':96}
print(updated2)
# Out:
# {'유비': 90, '관우': 96, '장비': 91, '조운': 94, '제갈량': 99, '황충': 70}

# %%
greats|=others #greats.update(others)와 동일
print(greats)
# Out:
# {'유비': 89, '관우': 95, '장비': 91, '조운': 94, '제갈량': 99, '황충': 70}

# %%
#123 딕셔너리 요소 정리하기: sorted()
greats = {'유비':89, '관우':95, '장비':91, '조운':94}
ret = sorted(greats)
print(ret)
# Out:
# ['관우', '유비', '장비', '조운']

# %%
ret = sorted(greats.items())
print(ret)
# Out:
# [('관우', 95), ('유비', 89), ('장비', 91), ('조운', 94)]

# %%
ret = sorted(greats.items(), reverse=True)
print(ret)
# Out:
# [('조운', 94), ('장비', 91), ('유비', 89), ('관우', 95)]

# %%
ret = sorted(greats.items(), key=lambda x:x[1])
print(ret)
# Out:
# [('유비', 89), ('장비', 91), ('조운', 94), ('관우', 95)]

# %%
ret = sorted(greats.items(), key=lambda x:x[1],reverse=True)
print(ret)
# Out:
# [('관우', 95), ('조운', 94), ('장비', 91), ('유비', 89)]

# %%
for name, level in ret:
  print(f'<{name}>의 레벨은 <{level}>입니다.')
# Out:
# <관우>의 레벨은 <95>입니다.
# <조운>의 레벨은 <94>입니다.
# <장비>의 레벨은 <91>입니다.
# <유비>의 레벨은 <89>입니다.
